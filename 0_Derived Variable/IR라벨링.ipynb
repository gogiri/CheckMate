# %%
import pandas as pd

# %%
df = pd.read_csv('../파생변수데이터셋/상장_파생.csv',index_col=0)

# %%
df
# Out:
#             회사명   거래소코드        회계년도     총자본증가율      순이익증가율    자기자본증가율  \
# 0      삼천당제약(주)     250  2013-12-01  27.277086  466.163338  37.626249
# 1      삼천당제약(주)     250  2014-12-01  11.013223  127.488875  17.147234
# 2      삼천당제약(주)     250  2015-12-01   6.823177    3.536727  10.480341
# 3      삼천당제약(주)     250  2016-12-01  11.317289  -12.648631  10.814120
# 4      삼천당제약(주)     250  2017-12-01  14.640655   47.486637  16.230043
# ...         ...     ...         ...        ...         ...        ...
# 10960   고스트스튜디오  950190  2021-12-01   7.620289  -21.580628  11.481446
# 10961   고스트스튜디오  950190  2022-12-01  -6.714755  -18.119045  -4.945890
# 10962    (주)소마젠  950200  2021-12-01 -10.364331   67.285728 -16.049119
# 10963    (주)소마젠  950200  2022-12-01   8.472746   85.155094  14.131181
# 10964  (주)네오이뮨텍  950220  2022-12-01 -25.216618  -15.097056 -26.137085
#
#           매출액증가율    유동자산증가율    유형자산증가율    비유동자산증가율  ...  자본분배율_산업평균차  \
# ...

# %%
df['통계청한국표준산업분류코드10차(대분류)']
# Out:
# 0        21
# 1        21
# 2        21
# 3        21
# 4        21
#          ..
# 10960    58
# 10961    58
# 10962    73
# 10963    73
# 10964    70
# Name: 통계청한국표준산업분류코드10차(대분류), Length: 10965, dtype: int64

# %%
data_list = [13, 14, 17, 26, 28, 29 ,31, 41, 42, 45, 46, 50, 62, 64, 66, 68, 94]

# %%
df['산업위험'] = df['통계청한국표준산업분류코드10차(대분류)'].apply(lambda x: 1 if x in data_list else 0)

# %%
df['산업위험']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 10960    0
# 10961    0
# 10962    0
# 10963    0
# 10964    0
# Name: 산업위험, Length: 10965, dtype: int64

# %%
df.to_csv('../파생변수데이터셋/상장_파생_ir.csv')
